# %% [markdown]
# <a href="https://colab.research.google.com/github/jarenmatthew/CMSC-197/blob/main/%5Bhw2%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download the dataset from:  https://github.com/bellawillrise/Introduction-to-Numerical-Computing-in-Python/
#
# Submit a pdf file, which is a rendered saved version of the jupyter notebook.  Make sure to execute all the codes so the output can be viewed in the pdf.
#
# Also include the link to the public github repository where the jupyter notebook for the assignment is uploaded.

# %% [markdown]
# Link to the github repository: https://github.com/jarenmatthew/CMSC-197

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("movie_metadata_cleaned.csv")

# %%
data.head(2)
# Out:
#    Unnamed: 0                                  movie_title  color  \
# 0           0                                    b'Avatar'  Color
# 1           1  b"Pirates of the Caribbean: At World's End"  Color
#
#     director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0   James Cameron                   723.0     178.0                      0.0
# 1  Gore Verbinski                   302.0     169.0                    563.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  ...  \
# 0                   855.0  Joel David Moore                  1000.0  ...
# 1                  1000.0     Orlando Bloom                 40000.0  ...
#
#    num_user_for_reviews language country  content_rating       budget  \
# 0                3054.0  English     USA           PG-13  237000000.0
# 1                1238.0  English     USA           PG-13  300000000.0
#
#   title_year  actor_2_facebook_likes imdb_score aspect_ratio  \
# ...

# %% [markdown]
# ## Get the top 10 directors with most movies directed and use a boxplot for their gross earnings
#
# 1.   List item
# 2.   List item

# %%
most_movies_directed = data['director_name'].value_counts().head(10).index
top_10_directors = data[data['director_name'].isin(most_movies_directed)]
plt.figure(figsize=(8,5))
sns.boxplot(x='director_name', y='gross', data=top_10_directors)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Plot the following variables in one graph:
#
# - num_critic_for_reviews
# - IMDB score
# - gross

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='num_critic_for_reviews', y='imdb_score', size='gross', hue='gross', data=data)
plt.xlabel('Number of Critic Reviews')
plt.ylabel('IMDB Score')
plt.show()

# %% [markdown]
# ## Compute Sales (Gross - Budget), add it as another column

# %%
data['sales'] = data['gross'] - data['budget']
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'movie_title',
#  'color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes',
#  'sales']

# %% [markdown]
# ## Which directors garnered the most total sales?

# %%
directors_with_most_sales = data.groupby('director_name')['sales'].sum().sort_values(ascending=False)
directors_with_most_sales.head(15)
# Out:
# director_name
# Steven Spielberg     2.451332e+09
# George Lucas         1.386641e+09
# James Cameron        1.199626e+09
# Joss Whedon          1.000887e+09
# Chris Columbus       9.417076e+08
# Peter Jackson        9.009693e+08
# Tim Burton           8.242755e+08
# Christopher Nolan    8.082276e+08
# Jon Favreau          7.693815e+08
# Francis Lawrence     7.555020e+08
# Jay Roach            7.155047e+08
# Michael Bay          6.442425e+08
# Sam Raimi            6.185742e+08
# Clint Eastwood       6.047211e+08
# Todd Phillips        5.817560e+08
# Name: sales, dtype: float64

# %% [markdown]
# ## Plot sales and average likes as a scatterplot. Fit it with a line.

# %%
data['average_likes'] = data[['director_facebook_likes', 'cast_total_facebook_likes', 'movie_facebook_likes']].mean(axis=1)
plt.figure(figsize=(8,5))
sns.regplot(x='average_likes', y='sales', data=data, line_kws={'color':'red'})
plt.xlabel('Average Likes')
plt.ylabel('Sales')
plt.title('Scatterplot of Average Likes and Sales')
plt.show()

# %% [markdown]
# ## Which of these genres are the most profitable? Plot their sales using different histograms, superimposed in the same axis.
#
# - Romance
# - Comedy
# - Action
# - Fantasy

# %%
romance_sales = data[data['genres'].str.contains('Romance')]['sales']
comedy_sales = data[data['genres'].str.contains('Comedy')]['sales']
action_sales = data[data['genres'].str.contains('Action')]['sales']
fantasy_sales = data[data['genres'].str.contains('Fantasy')]['sales']

sns.histplot(romance_sales, bins=20, color='pink', label='Romance', kde =True, alpha=0.5)
sns.histplot(comedy_sales, bins=20, color='red', label='Comedy', kde =True,alpha=0.5)
sns.histplot(action_sales, bins=20, color='blue', label='Action',kde =True, alpha=0.5)
sns.histplot(fantasy_sales, bins=20, color='orange', label='Fantasy', kde =True,alpha=0.5)
plt.legend(title='Genres')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Sales Distribution by Genre')
plt.show()

# %% [markdown]
# ## For each of movie, compute average likes of the three actors and store it as a new variable
#
# Read up on the mean function.
#
# Store it as a new column, average_actor_likes.

# %%
data['average_actor_likes'] = data[['actor_1_facebook_likes', 'actor_2_facebook_likes', 'actor_3_facebook_likes']].mean(axis=1)
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'movie_title',
#  'color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes',
#  'sales',
#  'average_likes',
#  'average_actor_likes']

# %% [markdown]
# ## Copying the whole dataframe

# %%
df = data.copy()
df.head()
# Out:
#    Unnamed: 0                                        movie_title  color  \
# 0           0                                          b'Avatar'  Color
# 1           1        b"Pirates of the Caribbean: At World's End"  Color
# 2           2                                         b'Spectre'  Color
# 3           3                           b'The Dark Knight Rises'  Color
# 4           4  b'Star Wars: Episode VII - The Force Awakens  ...      0
#
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0
# 4        Doug Walker                     0.0       0.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## Min-Max Normalization
#
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to a common scale, without distorting differences in the ranges of values. For machine learning, every dataset does not require normalization. It is required only when features have different ranges.
#
# The min-max approach (often called normalization) rescales the feature to a hard and fast range of [0,1] by subtracting the minimum value of the feature then dividing by the range. We can apply the min-max scaling in Pandas using the .min() and .max() methods.
#
# $$
# x_{scaled} = \frac{x-x_{min}}{x_{max}-x_{min}}
# $$

# %% [markdown]
# ### Normalize each numeric column (those that have types integer or float) of the copied dataframe (df)

# %%
numeric_columns = data.select_dtypes(include=['int','float']).columns
for column in numeric_columns:
  df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())


df.head()
# Out:
#    Unnamed: 0                                        movie_title  color  \
# 0    0.000000                                          b'Avatar'  Color
# 1    0.000198        b"Pirates of the Caribbean: At World's End"  Color
# 2    0.000397                                         b'Spectre'  Color
# 3    0.000595                           b'The Dark Knight Rises'  Color
# 4    0.000793  b'Star Wars: Episode VII - The Force Awakens  ...      0
#
#        director_name  num_critic_for_reviews  duration  \
# 0      James Cameron                0.889299  0.941799
# 1     Gore Verbinski                0.371464  0.894180
# 2         Sam Mendes                0.740467  0.783069
# 3  Christopher Nolan                1.000000  0.867725
# 4        Doug Walker                0.000000  0.000000
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                 0.000000                0.037174  Joel David Moore
# ...
